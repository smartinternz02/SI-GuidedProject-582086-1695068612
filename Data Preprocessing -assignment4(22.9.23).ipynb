# %% [markdown]
# # 1.Data Preprocessing

# %% [markdown]
# ## Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
df=pd.read_csv("Employee_Attrition.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ## checking the null values

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#as no null values are there

# %% [markdown]
# ## Data visualisation

# %%
df.corr()
# Out:
# <ipython-input-8-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-9-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# ## Outlier detection

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
sns.boxplot(df["MonthlyIncome"] )
# Out:
# <Axes: >

# %%
Q1 = df['MonthlyIncome'].quantile(0.25)
Q3 = df['MonthlyIncome'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 + (whisker_width*IQR)
df['MonthlyIncome']=np.where(df['MonthlyIncome']>upper_whisker,upper_whisker,np.where(df['MonthlyIncome']<lower_whisker,lower_whisker,df['MonthlyIncome']))

# %%
sns.boxplot(df["MonthlyIncome"] )
# Out:
# <Axes: >

# %%
sns.boxplot(df["NumCompaniesWorked"])
# Out:
# <Axes: >

# %%
Q1 = df['NumCompaniesWorked'].quantile(0.25)
Q3 = df['NumCompaniesWorked'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 + (whisker_width*IQR)
df['NumCompaniesWorked']=np.where(df['NumCompaniesWorked']>upper_whisker,upper_whisker,np.where(df['NumCompaniesWorked']<lower_whisker,lower_whisker,df['NumCompaniesWorked']))

# %%
sns.boxplot(df["NumCompaniesWorked"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["YearsWithCurrManager"])
# Out:
# <Axes: >

# %%
Q1 = df['YearsWithCurrManager'].quantile(0.25)
Q3 = df['YearsWithCurrManager'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 + (whisker_width*IQR)
df['YearsWithCurrManager']=np.where(df['YearsWithCurrManager']>upper_whisker,upper_whisker,np.where(df['YearsWithCurrManager']<lower_whisker,lower_whisker,df['YearsWithCurrManager']))

# %%
sns.boxplot(df["YearsSinceLastPromotion"])
# Out:
# <Axes: >

# %%
Q1 = df['YearsSinceLastPromotion'].quantile(0.25)
Q3 = df['YearsSinceLastPromotion'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 + (whisker_width*IQR)
df['YearsSinceLastPromotion']=np.where(df['YearsSinceLastPromotion']>upper_whisker,upper_whisker,np.where(df['YearsSinceLastPromotion']<lower_whisker,lower_whisker,df['YearsSinceLastPromotion']))

# %%
Q1 = df['YearsAtCompany'].quantile(0.25)
Q3 = df['YearsAtCompany'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 + (whisker_width*IQR)
df['YearsAtCompany']=np.where(df['YearsAtCompany']>upper_whisker,upper_whisker,np.where(df['YearsAtCompany']<lower_whisker,lower_whisker,df['YearsAtCompany']))

# %%
Q1 = df['YearsInCurrentRole'].quantile(0.25)
Q3 = df['YearsInCurrentRole'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 + (whisker_width*IQR)
df['YearsInCurrentRole']=np.where(df['YearsInCurrentRole']>upper_whisker,upper_whisker,np.where(df['YearsInCurrentRole']<lower_whisker,lower_whisker,df['YearsInCurrentRole']))

# %%
Q1 = df['TrainingTimesLastYear'].quantile(0.25)
Q3 = df['TrainingTimesLastYear'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 + (whisker_width*IQR)
df['TrainingTimesLastYear']=np.where(df['TrainingTimesLastYear']>upper_whisker,upper_whisker,np.where(df['YearsInCurrentRole']<lower_whisker,lower_whisker,df['TrainingTimesLastYear']))

# %%
Q1 = df['TotalWorkingYears'].quantile(0.25)
Q3 = df['TotalWorkingYears'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 + (whisker_width*IQR)
df['TotalWorkingYears']=np.where(df['TotalWorkingYears']>upper_whisker,upper_whisker,np.where(df['TotalWorkingYears']<lower_whisker,lower_whisker,df['TotalWorkingYears']))

# %%
#as almost all outliers are rectified

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# ## Splitting the dependent and independent variables

# %%
x=df.drop(columns="Attrition",axis=1)

# %%
y=df.iloc[:,1:2]

# %%
x.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# ...

# %%
y.head()
# Out:
#   Attrition
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
y.head()
# Out:
#   Attrition
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No

# %%
x.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# ...

# %%
x["BusinessTravel"]=le.fit_transform(x["BusinessTravel"])

# %%
x["Department"]=le.fit_transform(x["Department"])
x["EducationField"]=le.fit_transform(x["EducationField"])

# %%
x["Gender"]=le.fit_transform(x["Gender"])
x["JobRole"]=le.fit_transform(x["JobRole"])
x["MaritalStatus"]=le.fit_transform(x["MaritalStatus"])
x["Over18"]=le.fit_transform(x["Over18"])
x["OverTime"]=le.fit_transform(x["OverTime"])

# %%
x.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   41               2       1102           2                 1          2
# 1   49               1        279           1                 8          1
# 2   37               2       1373           1                 2          2
# 3   33               1       1392           1                 3          4
# 4   27               2        591           1                 2          1
#
#    EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# 0               1              1               1                        2
# 1               1              1               2                        3
# 2               4              1               4                        4
# 3               1              1               5                        4
# 4               3              1               7                        1
#
#    ...  RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   BusinessTravel            1470 non-null   int64
#  2   DailyRate                 1470 non-null   int64
#  3   Department                1470 non-null   int64
#  4   DistanceFromHome          1470 non-null   int64
#  5   Education                 1470 non-null   int64
#  6   EducationField            1470 non-null   int64
#  7   EmployeeCount             1470 non-null   int64
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   int64
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %% [markdown]
# ## Feature scaling

# %%
from sklearn.preprocessing import MinMaxScaler
ms=MinMaxScaler()

# %%
x_scaled=pd.DataFrame(ms.fit_transform(x),columns=x.columns)

# %%
x_scaled
# Out:
#            Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0     0.547619             1.0   0.715820         1.0          0.000000
# 1     0.738095             0.5   0.126700         0.5          0.250000
# 2     0.452381             1.0   0.909807         0.5          0.035714
# 3     0.357143             0.5   0.923407         0.5          0.071429
# 4     0.214286             1.0   0.350036         0.5          0.035714
# ...        ...             ...        ...         ...               ...
# 1465  0.428571             0.5   0.559771         0.5          0.785714
# 1466  0.500000             1.0   0.365784         0.5          0.178571
# 1467  0.214286             1.0   0.037938         0.5          0.107143
# 1468  0.738095             0.5   0.659270         1.0          0.035714
# 1469  0.380952             1.0   0.376521         0.5          0.250000
#
#       Education  EducationField  EmployeeCount  EmployeeNumber  \
# ...

# %% [markdown]
# ## splitting data in to training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=0)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((1176, 34), (294, 34), (1176, 1), (294, 1))

# %% [markdown]
# # 2.Model Building

# %% [markdown]
# ### Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
pred=lr.predict(x_test)

# %% [markdown]
# ### Evaluation Metric for Logistic Regression

# %%
#Accuracy score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score,roc_curve

# %%
accuracy_score(y_test,pred)
# Out:
# 0.8741496598639455

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[240,   5],
#        [ 32,  17]])

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.88      0.98      0.93       245
#          Yes       0.77      0.35      0.48        49
#
#     accuracy                           0.87       294
#    macro avg       0.83      0.66      0.70       294
# weighted avg       0.86      0.87      0.85       294

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred1=dtc.predict(x_test)

# %%
pred1
# Out:
# array(['No', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'No',
#        'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No',
#        'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes',
# ...

# %% [markdown]
# ### Evaluation Metric for decision tree

# %%
#Accuracy score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score,roc_curve

# %%
accuracy_score(y_test,pred1)
# Out:
# 0.7653061224489796

# %%
confusion_matrix(y_test,pred1)
# Out:
# array([[208,  37],
#        [ 32,  17]])

# %%
print(classification_report(y_test,pred1))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.87      0.85      0.86       245
#          Yes       0.31      0.35      0.33        49
#
#     accuracy                           0.77       294
#    macro avg       0.59      0.60      0.59       294
# weighted avg       0.77      0.77      0.77       294

# %%
accuracy_score(y_test,pred1)
# Out:
# 0.7653061224489796
